# %% [markdown]
# # 05_evaluation
# - Author:
# - Date: 2025-10-23
# - Goal: Confusion Matrix, t-SNE, Grad-CAM
# - Input:
# - Output:
# - Metrics: acc@val, loss@train
# - Repro: seed=42, device=auto, config=../configs/
