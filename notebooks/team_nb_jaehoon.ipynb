# %% [markdown]
# # 팀 노트북 — 재훈
# 숫자/전경색/배경색 예측 실험을 위한 개인 스크래치패드입니다.

# %% [markdown]
# ## 실험 로그
# - 사용한 모델과 하이퍼파라미터를 요약하세요.
# - 큰 산출물은 Git 외부(로컬/Drive)에 저장합니다.

# %%
# 여기에서 실험 코드를 작성하세요
import pathlib
import numpy as np
from sklearn.model_selection import train_test_split
