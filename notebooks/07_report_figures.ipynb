# %% [markdown]
# # 07_report_figures
# - Author:
# - Date: 2025-10-23
# - Goal: 보고서/발표용 그림 자동 생성
# - Input:
# - Output:
# - Metrics: acc@val, loss@train
# - Repro: seed=42, device=auto, config=../configs/
