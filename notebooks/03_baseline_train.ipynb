# %% [markdown]
# # 03_baseline_train
# - Author:
# - Date: 2025-10-23
# - Goal: Baseline CNN 학습 및 로깅
# - Input:
# - Output:
# - Metrics: acc@val, loss@train
# - Repro: seed=42, device=auto, config=../configs/
