# %% [markdown]
# # 04_improved_train
# - Author:
# - Date: 2025-10-23
# - Goal: 개선모델(증강/정규화/옵션:Attention)
# - Input:
# - Output:
# - Metrics: acc@val, loss@train
# - Repro: seed=42, device=auto, config=../configs/
