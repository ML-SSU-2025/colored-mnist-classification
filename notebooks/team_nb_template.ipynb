# %% [markdown]
# # 팀 노트북 템플릿
# Colored MNIST 관련 개인 실험을 기록할 때 사용하세요.
# 실험 목적, 사용한 데이터 버전, 주요 노트를 아래에 정리합니다.

# %% [markdown]
# ## 환경 설정
# 공식 전처리 노트북이 생성한 산출물 또는 `data/raw` 아래의 원본 데이터를 불러오세요.
# 실험은 반드시 클래식 ML 범위(KNN/SVM/DT/RF/LogReg) 안에서 진행합니다.

# %%
# 예시: 핵심 라이브러리 로딩
import numpy as np
import pandas as pd
from sklearn import model_selection
